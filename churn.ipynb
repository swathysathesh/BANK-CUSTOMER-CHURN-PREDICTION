# %% [markdown]
# <a href="https://colab.research.google.com/github/swathysathesh/bank-customer-churn-prediction/blob/main/churn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Bank Customer Churn Prediction**

# %% [markdown]
# ![dataset-cover 4.png](data:image/png;base64,...)

# %% [markdown]
# It is the dataset of a U.S. bank customer for getting the information that , this particular customer will leave bank or not.

# %% [markdown]
# #About the dataset

# %% [markdown]
# **RowNumber**: Row Number Of dataset
#
# **CustomerId**: CustomerID is given
#
# **Surname**: Surname of the customer
#
# **CreditScore**: Credit Score of customer
#
# **Geography**: location of customer
#
#
# **Gender:** Gender whether male or female
#
# **Age:** Age of the customer
#
# **Tenure:** From how many years customer is in bank
#
# **Balance:** Average balance of customer
#
# **NumOfProducts:** Number of bank product facilities customer is using
#
# **HasCrCard:**If the customer has a Credit Card
#
# **IsActiveMember:** If the member is active in using the banking services
#
# **EstimatedSalary**: Estimated Salary of the customer
#
# **Exited**: Customer left the bank (Churn)

# %% [markdown]
# # Importing sufficient python libraries and importing the dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('/content/Churn_Modelling (2).csv')
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %% [markdown]
# #Dataset Overview

# %% [markdown]
# If we want to see the first five rows of our data table we have to call the head() function.

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %% [markdown]
# If we want to see the last five rows of our data table we have to call the tail() function.

# %%
df.tail()
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 9995         96270.64       0
# 9996        101699.77       0
# ...

# %% [markdown]
# To observe the total number of rows and columns in the table, we simply have to call shape.

# %%
df.shape
# Out:
# (10000, 14)

# %% [markdown]
# we are going to check the total column list by calling columns

# %%
df.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %% [markdown]
# #Dataset Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %% [markdown]
# **Number of Entries:** The dataset consists of 10000  entries.
#
# **Columns:** The dataset contains 14 columns,
# **Data Types:**
#
# * 3 coumns are of the object data type
#
# * 9 columns are of the int64 data type, representing integer values.
#
# * 2 columns are of the float64 data type, which typically
#  denotes decimal values.

# %% [markdown]
# displaying description of the integer columns of a dataframe we have to call describe() function

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %% [markdown]
# displaying description about the object columns in a table

# %%
df.describe(include='O')
# Out:
#        Surname Geography Gender
# count    10000     10000  10000
# unique    2932         3      2
# top      Smith    France   Male
# freq        32      5014   5457

# %% [markdown]
# #Data types

# %% [markdown]
# To observe the data types, we simply have to call dtypes

# %%
df.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %% [markdown]
# #To Checking missing values

# %% [markdown]
# For checking the null value available in our dataset we have to use the isna() function that means is the null value available And a sum function to do a summation of all the missing values in the dataset.

# %%
df.isna().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %% [markdown]
# # Checking unique value for each variable

# %%
for i in df.columns:
  print(i,":",df[i].unique())
# Out:
# RowNumber : [    1     2     3 ...  9998  9999 10000]
# CustomerId : [15634602 15647311 15619304 ... 15584532 15682355 15628319]
# Surname : ['Hargrave' 'Hill' 'Onio' ... 'Kashiwagi' 'Aldridge' 'Burbidge']
# CreditScore : [619 608 502 699 850 645 822 376 501 684 528 497 476 549 635 616 653 587
#  726 732 636 510 669 846 577 756 571 574 411 591 533 553 520 722 475 490
#  804 582 472 465 556 834 660 776 829 637 550 698 585 788 655 601 656 725
#  511 614 742 687 555 603 751 581 735 661 675 738 813 657 604 519 664 678
#  757 416 665 777 543 506 493 652 750 729 646 647 808 524 769 730 515 773
#  814 710 413 623 670 622 785 605 479 685 538 562 721 628 668 828 674 625
#  432 770 758 795 686 789 589 461 584 579 663 682 793 691 485 650 754 535
#  716 539 706 586 631 717 800 683 704 615 667 484 480 578 512 606 597 778
#  514 525 715 580 807 521 759 516 711 618 643 671 689 620 676 572 695 592
#  567 694 547 594 673 610 767 763 712 703 662 659 523 772 545 634 739 771
# ...

# %% [markdown]
# #Data preprocessing

# %% [markdown]
# drop unneccessary columns

# %%
df.drop(['RowNumber','Surname','CustomerId'],axis=1,inplace=True)

# %% [markdown]
# Dropping duplicate values

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# # Distributions of Numeric Features

# %%
# Plot histogram grid
df.hist(figsize=(14,14))

plt.show()

# %% [markdown]
# #Data Visualiztion

# %% [markdown]
# Customer is exit or not

# %%
plt.pie(x=df['Exited'].value_counts(),autopct='%1.2f%%',labels=[0,1])
plt.legend()

# %% [markdown]
# from the above insights we can see that 79.63% is not exited remaining 20% is exited the bank

# %%
sns.countplot(x='Gender',hue='Exited',data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %% [markdown]
# from above insight 3000+ females are not exited and 1000+ female customers are exited the bank.Then 4000+ males customers are not exited the bank and 1000 males are exited the bank.

# %%
sns.countplot(x='Geography',data=df,palette='hot')
# Out:
# <ipython-input-171-671ade91d32a>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Geography',data=df,palette='hot')
# <Axes: xlabel='Geography', ylabel='count'>

# %% [markdown]
# They are three different geography France,spain,germany most of them are france

# %%
plt.figure(figsize=(12, 6))
sns.histplot(df['Age'], bins=30, kde=True, color='navy', alpha=0.7)
plt.title('Distribution of Customer Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='Tenure', bins=30, kde=True, color='purple', alpha=0.7, label='Tenure Distribution')
plt.title('Customer Tenure Distribution')
plt.xlabel('Tenure (Years)')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %% [markdown]
# #Heat Map

# %%
d1=df.select_dtypes(include=['number'])
sns.heatmap(d1.corr(),annot=True)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,8))
d1.corr()['Exited'].sort_values(ascending =False).plot(kind='bar',title='Correlation Graph vs Exited')
plt.grid()

# %% [markdown]
# #Pairplot

# %%
sns.pairplot(data=df)

# %% [markdown]
# #Handling categorical values

# %% [markdown]
# converting categorical values to numerical values.label encode assigns a numerical value to each category.

# %%
from sklearn.preprocessing import LabelEncoder
lab=LabelEncoder()
df['Geography']=lab.fit_transform(df['Geography'])
df['Gender']=lab.fit_transform(df['Gender'])

# %%
df.dtypes
# Out:
# CreditScore          int64
# Geography            int64
# Gender               int64
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %% [markdown]
# #Detecting Outliers

# %%
sns.boxplot(x='CreditScore',data=df)
# Out:
# <Axes: xlabel='CreditScore'>

# %%
sns.boxplot(x='Age',data=df)
# Out:
# <Axes: xlabel='Age'>

# %%
q1=df['Age'].quantile(0.25)
q3=df['Age'].quantile(0.75)
iqr=q3-q1

# %%
df = df[~((df['Age']<(q1-1.5*iqr))|(df['Age']>(q3+1.5*iqr)))]
df.reset_index(inplace=True)
df.shape
# Out:
# (9641, 12)

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %% [markdown]
# #Balancing Data

# %%
from imblearn.over_sampling import SMOTE
smote=SMOTE()
x_resampled,y_resampled=smote.fit_resample(x,y)
y_resampled.value_counts()
# Out:
# Exited
# 1    7677
# 0    7677
# Name: count, dtype: int64

# %%
x1=x_resampled.values
x1
# Out:
# array([[0.00000000e+00, 6.19000000e+02, 0.00000000e+00, ...,
#         1.00000000e+00, 1.00000000e+00, 1.01348880e+05],
#        [1.00000000e+00, 6.08000000e+02, 2.00000000e+00, ...,
#         0.00000000e+00, 1.00000000e+00, 1.12542580e+05],
#        [2.00000000e+00, 5.02000000e+02, 0.00000000e+00, ...,
#         1.00000000e+00, 0.00000000e+00, 1.13931570e+05],
#        ...,
#        [1.53400000e+03, 5.52000000e+02, 1.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 5.24600268e+04],
#        [3.48200000e+03, 7.89000000e+02, 1.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 9.18808157e+04],
#        [3.06500000e+03, 5.59000000e+02, 0.00000000e+00, ...,
#         1.00000000e+00, 1.00000000e+00, 1.71016286e+05]])

# %%
y1=y_resampled.values
y1
# Out:
# array([1, 0, 1, ..., 1, 1, 1])

# %% [markdown]
# #split into train test

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x1,y1,test_size=0.30,random_state=42)
x_train
# Out:
# array([[3.4500000e+03, 5.1300000e+02, 0.0000000e+00, ..., 1.0000000e+00,
#         0.0000000e+00, 1.0502846e+05],
#        [8.9830000e+03, 7.2300000e+02, 1.0000000e+00, ..., 1.0000000e+00,
#         0.0000000e+00, 1.2123965e+05],
#        [3.4650000e+03, 6.9200000e+02, 1.0000000e+00, ..., 0.0000000e+00,
#         0.0000000e+00, 1.6462143e+05],
#        ...,
#        [5.5920000e+03, 5.7600000e+02, 2.0000000e+00, ..., 0.0000000e+00,
#         0.0000000e+00, 7.2306070e+04],
#        [8.8900000e+02, 5.4200000e+02, 0.0000000e+00, ..., 0.0000000e+00,
#         1.0000000e+00, 1.0350740e+04],
#        [7.5380000e+03, 6.0100000e+02, 2.0000000e+00, ..., 1.0000000e+00,
#         0.0000000e+00, 1.4665280e+04]])

# %% [markdown]
# #Standardization

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
sc.fit(x_train)
x_test=sc.transform(x_test)

# %% [markdown]
# #Model creation

# %% [markdown]
# #Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
# Out:
# array([0, 1, 0, ..., 1, 1, 1])

# %% [markdown]
# Perfomance Evaluation

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
# Out:
# 0.7219448665074886
#               precision    recall  f1-score   support
#
#            0       0.72      0.75      0.73      2342
#            1       0.73      0.70      0.71      2265
#
#     accuracy                           0.72      4607
#    macro avg       0.72      0.72      0.72      4607
# weighted avg       0.72      0.72      0.72      4607
#
# [[1745  597]
#  [ 684 1581]]

# %% [markdown]
# #RandomForest

# %%
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier(criterion='gini')
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %% [markdown]
# perfomance evalution

# %%
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
# Out:
# 0.5163881050575212
#               precision    recall  f1-score   support
#
#            0       0.51      1.00      0.68      2342
#            1       0.89      0.02      0.04      2265
#
#     accuracy                           0.52      4607
#    macro avg       0.70      0.51      0.36      4607
# weighted avg       0.70      0.52      0.36      4607
#
# [[2337    5]
#  [2223   42]]
